# %%
from src.common.bigquery_connector import BigQueryManager

# %%
import pandas as pd
import numpy as np

from datetime import datetime
from src.common.cloud_storage_connector import CloudStorage
from src.common.bigquery_connector import BigQueryManager
from src.config import settings
import json

# %%
def process_orders(json):

    try:
        df_ = pd.DataFrame()

        for sale in json:

            structured_sale = {
              'reason': sale['payments'][0].get('reason'),
              'status_code': sale['payments'][0].get('status_code'),
              'total_paid_amount': sale['payments'][0].get('total_paid_amount'),
              'operation_type': sale['payments'][0].get('operation_type'),
              'transaction_amount': sale['payments'][0].get('transaction_amount'),
              'transaction_amount_refunded': sale['payments'][0].get('transaction_amount_refunded'),
              'date_approved': sale['payments'][0].get('date_approved'),
              'collector_id': sale['payments'][0]['collector'].get('id') if 'collector' in sale['payments'][0] else None,
              'coupon_id': sale['payments'][0].get('coupon_id'),
              'installments': sale['payments'][0].get('installments'),
              'authorization_code': sale['payments'][0].get('authorization_code'),
              'taxes_amount': sale['payments'][0].get('taxes_amount'),
              'payment_id': sale['payments'][0].get('id'),
              'date_last_modified': sale['payments'][0].get('date_last_modified'),
              'coupon_amount': sale['payments'][0].get('coupon_amount'),
              'shipping_cost': sale['payments'][0].get('shipping_cost'),
              'installment_amount': sale['payments'][0].get('installment_amount'),
              'activation_uri': sale['payments'][0].get('activation_uri'),
              'overpaid_amount': sale['payments'][0].get('overpaid_amount'),
              'card_id': sale['payments'][0].get('card_id'),
              'status_detail': sale['payments'][0].get('status_detail'),
              'issuer_id': sale['payments'][0].get('issuer_id'),
              'payment_method_id': sale['payments'][0].get('payment_method_id'),
              'payment_type': sale['payments'][0].get('payment_type'),
              'deferred_period': sale['payments'][0].get('deferred_period'),
              'atm_transfer_reference_transaction_id': sale['payments'][0]['atm_transfer_reference'].get('transaction_id') if 'atm_transfer_reference' in sale['payments'][0] else None,
              'atm_transfer_reference_company_id': sale['payments'][0]['atm_transfer_reference'].get('company_id') if 'atm_transfer_reference' in sale['payments'][0] else None,
              'site_id': sale['payments'][0].get('site_id'),
              'payer_id': sale['payments'][0].get('payer_id'),
              'order_id': sale['payments'][0].get('order_id'),
              'currency_id': sale['payments'][0].get('currency_id'),
              'payment_status': sale['payments'][0].get('status'),
              'shipping_id': sale.get('shipping', {}).get('id'),
              'fulfilled': sale.get('fulfilled'),
              'seller_id': sale.get('seller', {}).get('id'),
              'buyer_id': sale.get('buyer', {}).get('id'),
              'item_id': sale['order_items'][0]['item'].get('id'),
              'item_title': sale['order_items'][0]['item'].get('title'),
              'item_category_id': sale['order_items'][0]['item'].get('category_id'),
              'item_variation_id': sale['order_items'][0]['item'].get('variation_id'),
              'seller_custom_field': sale['order_items'][0]['item'].get('seller_custom_field'),
              'global_price': sale['order_items'][0]['item'].get('global_price'),
              'net_weight': sale['order_items'][0]['item'].get('net_weight'),
              'warranty': sale['order_items'][0]['item'].get('warranty'),
              'condition': sale['order_items'][0]['item'].get('condition'),
              'seller_sku': sale['order_items'][0]['item'].get('seller_sku'),
              'quantity': sale['order_items'][0].get('quantity'),
              'unit_price': sale['order_items'][0].get('unit_price'),
              'full_unit_price': sale['order_items'][0].get('full_unit_price'),
              'manufacturing_days': sale['order_items'][0].get('manufacturing_days'),
              'requested_quantity_measure': sale['order_items'][0]['requested_quantity'].get('measure') if 'requested_quantity' in sale['order_items'][0] else None,
              'requested_quantity_value': sale['order_items'][0]['requested_quantity'].get('value') if 'requested_quantity' in sale['order_items'][0] else None,
              'sale_fee': sale['order_items'][0].get('sale_fee'),
              'listing_type_id': sale['order_items'][0].get('listing_type_id'),
              'base_exchange_rate': sale['order_items'][0].get('base_exchange_rate'),
              'base_currency_id': sale['order_items'][0].get('base_currency_id'),
              'bundle': sale['order_items'][0].get('bundle'),
              'element_id': sale['order_items'][0].get('element_id'),
              'date_created': sale.get('date_created'),
              'date_closed': sale.get('date_closed'),
              'status': sale.get('status'),
              'expiration_date': sale.get('expiration_date'),
              'date_last_updated': sale.get('date_last_updated'),
              'last_updated': sale.get('last_updated'),
              'comment': sale.get('comment'),
              'pack_id': sale.get('pack_id'),
              'coupon_amount': sale.get('coupon', {}).get('amount'),
              'coupon_id': sale.get('coupon', {}).get('id'),
              'shipping_cost': sale.get('shipping_cost'),
              'pickup_id': sale.get('pickup_id'),
              'status_detail': sale.get('status_detail'),
              'total_amount': sale.get('total_amount'),
              'paid_amount': sale.get('paid_amount'),
              'context_application': sale.get('context', {}).get('application'),
              'context_product_id': sale.get('context', {}).get('product_id'),
              'context_channel': sale.get('context', {}).get('channel'),
              'context_site': sale.get('context', {}).get('site'),
              }

            df_ = pd.concat([df_, pd.DataFrame([structured_sale])], ignore_index = True)
    
    except Exception as e:
        print(f'Error processing json: {e}')
    
    return df_

# %%
request = test_data = {
  "access_token": None,
  "client_id": "4959083987776428",
  "client_secret": "Hw9wWSydd8PMvMEJewWoMvKGYMAWyKEw",
  "seller_id": 189643563,
  "store_name": "hubsmarthome"
}

# %%
content['results']
# Out:
# [{'payments': [{'reason': 'Tomada Inteligente Wifi 20a Alexa Pro Max Ekaza Homol Anatel',
#     'status_code': None,
#     'total_paid_amount': 48.45,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 48.45,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:14:00.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87914198824,
#     'date_last_modified': '2024-09-14T20:16:10.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:12:53.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '12501',
#     'payment_method_id': 'pix',
#     'payment_type': 'bank_transfer',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': '1'},
#     'site_id': 'MLB',
#     'payer_id': 3982584,
#     'order_id': 2000009301635216,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:15:01.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43842807477},
#   'date_closed': '2024-09-14T20:15:01.000-04:00',
#   'id': 2000009301635216,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3746697587',
#      'title': 'Tomada Inteligente Wifi 20a Alexa Pro Max Ekaza Homol Anatel',
#      'category_id': 'MLB269930',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKAT-T205-20A'},
#     'quantity': 1,
#     'unit_price': 48.45,
#     'full_unit_price': 78.99,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 1},
#     'sale_fee': 8.9,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 1}],
#   'date_last_updated': '2024-09-15T00:17:13+00:00',
#   'last_updated': '2024-09-14T20:17:12.000-04:00',
#   'comment': None,
#   'pack_id': None,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:12:53.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['catalog', 'paid', 'not_delivered'],
#   'buyer': {'id': 3982584, 'nickname': 'TEBATEBA'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 48.45,
#   'paid_amount': 48.45,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': ['catalog']}},
#  {'payments': [{'reason': 'Atuador Inteligente Wifi Válvula Registro Água E Gás Alexa',
#     'status_code': None,
#     'total_paid_amount': 296.97,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 296.97,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:15:45.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87614711525,
#     'date_last_modified': '2024-09-14T20:17:24.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:15:45.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 64450501,
#     'order_id': 2000009301655266,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:15:46.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43842994220},
#   'date_closed': '2024-09-14T20:15:46.000-04:00',
#   'id': 2000009301655266,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3750403647',
#      'title': 'Atuador Inteligente Wifi Válvula Registro Água E Gás Alexa',
#      'category_id': 'MLB271275',
#      'variation_id': 180777186684,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [{'name': 'Voltagem',
#        'id': 'VOLTAGE',
#        'value_id': '198812',
#        'value_name': '110V/220V'}],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'HIVAG'},
#     'quantity': 3,
#     'unit_price': 98.99,
#     'full_unit_price': 149.99,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 3},
#     'sale_fee': 1.97,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 1}],
#   'date_last_updated': '2024-09-15T00:17:25+00:00',
#   'last_updated': '2024-09-14T20:17:24.000-04:00',
#   'comment': None,
#   'pack_id': 2000006319909571,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:15:43.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'mshops', 'paid', 'not_delivered'],
#   'buyer': {'id': 64450501, 'nickname': 'BRUNOSOUSAAGUILAR'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 296.97,
#   'paid_amount': 296.97,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'mshops',
#    'site': 'MLB',
#    'flows': []}},
#  {'payments': [{'reason': 'Lâmpada Inteligente Ekaza Ekhm-t609 Rgb A60 9w+3rgb Smart Alexa E Google Home',
#     'status_code': None,
#     'total_paid_amount': 32,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 32,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:21:31.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87914907238,
#     'date_last_modified': '2024-09-14T20:22:46.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:21:31.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 73795363,
#     'order_id': 2000009301698204,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:21:32.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43842828995},
#   'date_closed': '2024-09-14T20:21:32.000-04:00',
#   'id': 2000009301698204,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3891206678',
#      'title': 'Lâmpada Inteligente Ekaza Ekhm-t609 Rgb A60 9w+3rgb Smart Alexa E Google Home',
#      'category_id': 'MLB8462',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKGC-T261-E27'},
#     'quantity': 1,
#     'unit_price': 32,
#     'full_unit_price': 40,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 1},
#     'sale_fee': 9.68,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 3}],
#   'date_last_updated': '2024-09-15T00:23:03+00:00',
#   'last_updated': '2024-09-14T20:23:02.000-04:00',
#   'comment': None,
#   'pack_id': 2000006319925331,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:21:28.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'catalog', 'paid', 'not_delivered'],
#   'buyer': {'id': 73795363, 'nickname': 'ANDREWS RICHARD'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 32,
#   'paid_amount': 32,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': ['catalog']}},
#  {'payments': [{'reason': 'Interruptor Relé Inteligente Zigbee 4 Canais Mini Smart Switch Novadigital Tuya Alexa  Cor Preto 110v/220v',
#     'status_code': None,
#     'total_paid_amount': 224.97,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 224.97,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:22:32.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87914968860,
#     'date_last_modified': '2024-09-14T20:22:39.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:22:31.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 168027628,
#     'order_id': 2000009301698550,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:22:32.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43842830081},
#   'date_closed': '2024-09-14T20:22:32.000-04:00',
#   'id': 2000009301698550,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3757187603',
#      'title': 'Interruptor Relé Inteligente Zigbee 4 Canais Mini Smart Switch Novadigital Tuya Alexa  Cor Preto 110v/220v',
#      'category_id': 'MLB269928',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'MS-106ZB4'},
#     'quantity': 3,
#     'unit_price': 74.99,
#     'full_unit_price': 88.22,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 3},
#     'sale_fee': 11.09,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 5}],
#   'date_last_updated': '2024-09-15T05:37:33+00:00',
#   'last_updated': '2024-09-15T01:33:12.000-04:00',
#   'comment': None,
#   'pack_id': 2000006319928515,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:21:49.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'catalog', 'paid', 'not_delivered'],
#   'buyer': {'id': 168027628, 'nickname': 'ANDERSONOPSFELDER'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 224.97,
#   'paid_amount': 224.97,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': ['catalog']}},
#  {'payments': [{'reason': 'Interruptor Mini R2 Wifi Automação Alexa E Google Home',
#     'status_code': None,
#     'total_paid_amount': 48.41,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 34.78,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:23:18.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': '031260',
#     'taxes_amount': 0,
#     'id': 87615432527,
#     'date_last_modified': '2024-09-14T20:23:24.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 13.63,
#     'installment_amount': 48.41,
#     'date_created': '2024-09-14T20:23:16.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': 9253594142,
#     'status_detail': 'accredited',
#     'issuer_id': '24',
#     'payment_method_id': 'master',
#     'payment_type': 'credit_card',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 149136389,
#     'order_id': 2000009301689570,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:23:18.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43842834025},
#   'date_closed': '2024-09-14T20:23:18.000-04:00',
#   'id': 2000009301689570,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3204702696',
#      'title': 'Interruptor Mini R2 Wifi Automação Alexa E Google Home',
#      'category_id': 'MLB269928',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKHY-T109-WB'},
#     'quantity': 1,
#     'unit_price': 34.78,
#     'full_unit_price': 51.92,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 1},
#     'sale_fee': 10,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 1}],
#   'date_last_updated': '2024-09-15T00:24:53+00:00',
#   'last_updated': '2024-09-14T20:24:52.000-04:00',
#   'comment': None,
#   'pack_id': None,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:23:15.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['paid', 'not_delivered'],
#   'buyer': {'id': 149136389, 'nickname': 'RAMA6424810'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 34.78,
#   'paid_amount': 48.41,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': []}},
#  {'payments': [{'reason': 'Câmera Ré Automotiva Mini Tartaruga Universal Visão Noturna Eks Tech',
#     'status_code': None,
#     'total_paid_amount': 35.99,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 35.99,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:24:26.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87915114964,
#     'date_last_modified': '2024-09-14T20:24:32.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:24:25.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 363879704,
#     'order_id': 2000009301711210,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:24:26.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43843016128},
#   'date_closed': '2024-09-14T20:24:26.000-04:00',
#   'id': 2000009301711210,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3469014173',
#      'title': 'Câmera Ré Automotiva Mini Tartaruga Universal Visão Noturna Eks Tech',
#      'category_id': 'MLB116489',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKXZ-310'},
#     'quantity': 1,
#     'unit_price': 35.99,
#     'full_unit_price': 59.99,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 1},
#     'sale_fee': 7.8,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 2}],
#   'date_last_updated': '2024-09-15T05:14:38+00:00',
#   'last_updated': '2024-09-14T20:41:43.000-04:00',
#   'comment': None,
#   'pack_id': 2000006319941151,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:24:22.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'catalog', 'paid', 'not_delivered'],
#   'buyer': {'id': 363879704, 'nickname': 'SOUZAALTAIR44'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 35.99,
#   'paid_amount': 35.99,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': ['catalog']}},
#  {'payments': [{'reason': 'Interruptor Mini Zigbee 2 Canais Automação Alexa E Google',
#     'status_code': None,
#     'total_paid_amount': 119.98,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 119.98,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:25:12.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87915141526,
#     'date_last_modified': '2024-09-14T20:25:21.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:25:11.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 54865072,
#     'order_id': 2000009301716750,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:25:12.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43842839009},
#   'date_closed': '2024-09-14T20:25:12.000-04:00',
#   'id': 2000009301716750,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3326182895',
#      'title': 'Interruptor Mini Zigbee 2 Canais Automação Alexa E Google',
#      'category_id': 'MLB269928',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKAC-T3092Z'},
#     'quantity': 2,
#     'unit_price': 59.99,
#     'full_unit_price': 59.99,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 2},
#     'sale_fee': 1.19,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 1}],
#   'date_last_updated': '2024-09-15T06:02:54+00:00',
#   'last_updated': '2024-09-14T20:26:48.000-04:00',
#   'comment': None,
#   'pack_id': 2000006319940479,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:25:09.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'mshops', 'paid', 'not_delivered'],
#   'buyer': {'id': 54865072, 'nickname': 'PAULO.RAMOS2'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 119.98,
#   'paid_amount': 119.98,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'mshops',
#    'site': 'MLB',
#    'flows': []}},
#  {'payments': [{'reason': 'Hub Zigbee 3.0 Bridge Gateway Cabo Rj45 Alexa E Google',
#     'status_code': None,
#     'total_paid_amount': 159.99,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 159.99,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:25:13.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87915115800,
#     'date_last_modified': '2024-09-14T20:26:25.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:25:13.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 54865072,
#     'order_id': 2000009301711958,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:25:14.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43842839009},
#   'date_closed': '2024-09-14T20:25:14.000-04:00',
#   'id': 2000009301711958,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3752786750',
#      'title': 'Hub Zigbee 3.0 Bridge Gateway Cabo Rj45 Alexa E Google',
#      'category_id': 'MLB7070',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKAT-T3010L'},
#     'quantity': 1,
#     'unit_price': 159.99,
#     'full_unit_price': 159.99,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 1},
#     'sale_fee': 3.18,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 3}],
#   'date_last_updated': '2024-09-15T06:02:54+00:00',
#   'last_updated': '2024-09-14T20:26:46.000-04:00',
#   'comment': None,
#   'pack_id': 2000006319940479,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:25:09.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'mshops', 'paid', 'not_delivered'],
#   'buyer': {'id': 54865072, 'nickname': 'PAULO.RAMOS2'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 159.99,
#   'paid_amount': 159.99,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'mshops',
#    'site': 'MLB',
#    'flows': []}},
#  {'payments': [{'reason': 'Fechadura Inteligente Biométrica Zigbee Eletrônica Digital',
#     'status_code': None,
#     'total_paid_amount': 579.99,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 579.99,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:25:16.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87615515209,
#     'date_last_modified': '2024-09-14T20:25:22.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:25:15.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 54865072,
#     'order_id': 2000009301711956,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:25:16.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43842839009},
#   'date_closed': '2024-09-14T20:25:16.000-04:00',
#   'id': 2000009301711956,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3458633905',
#      'title': 'Fechadura Inteligente Biométrica Zigbee Eletrônica Digital',
#      'category_id': 'MLB194301',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKAV-T229Z'},
#     'quantity': 1,
#     'unit_price': 579.99,
#     'full_unit_price': 579.99,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 1},
#     'sale_fee': 11.54,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 2}],
#   'date_last_updated': '2024-09-15T06:02:54+00:00',
#   'last_updated': '2024-09-14T20:26:51.000-04:00',
#   'comment': None,
#   'pack_id': 2000006319940479,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:25:09.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'mshops', 'paid', 'not_delivered'],
#   'buyer': {'id': 54865072, 'nickname': 'PAULO.RAMOS2'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 579.99,
#   'paid_amount': 579.99,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'mshops',
#    'site': 'MLB',
#    'flows': []}},
#  {'payments': [{'reason': 'Tomada Inteligente Wifi 20a Alexa Pro Max Ekaza Homol Anatel',
#     'status_code': None,
#     'total_paid_amount': 48.45,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 48.45,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:26:14.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': '177153',
#     'taxes_amount': 0,
#     'id': 87915290532,
#     'date_last_modified': '2024-09-14T20:27:24.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': 48.45,
#     'date_created': '2024-09-14T20:26:13.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': 9413640370,
#     'status_detail': 'accredited',
#     'issuer_id': '25',
#     'payment_method_id': 'visa',
#     'payment_type': 'credit_card',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 183152996,
#     'order_id': 2000009301722426,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:26:15.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43842841669},
#   'date_closed': '2024-09-14T20:26:15.000-04:00',
#   'id': 2000009301722426,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3746697587',
#      'title': 'Tomada Inteligente Wifi 20a Alexa Pro Max Ekaza Homol Anatel',
#      'category_id': 'MLB269930',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKAT-T205-20A'},
#     'quantity': 1,
#     'unit_price': 48.45,
#     'full_unit_price': 78.99,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 1},
#     'sale_fee': 8.9,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 1}],
#   'date_last_updated': '2024-09-15T00:28:27+00:00',
#   'last_updated': '2024-09-14T20:28:26.000-04:00',
#   'comment': None,
#   'pack_id': None,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:26:12.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['catalog', 'paid', 'not_delivered'],
#   'buyer': {'id': 183152996, 'nickname': 'DANIELLEQUIRINO'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 48.45,
#   'paid_amount': 48.45,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': ['catalog']}},
#  {'payments': [{'reason': 'Tomada Inteligente Wifi Ekaza 10a Com Medição Google Alexa Cor Roxo',
#     'status_code': None,
#     'total_paid_amount': 46.58,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 46.58,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:27:34.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87615792139,
#     'date_last_modified': '2024-09-14T20:27:39.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:27:34.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 80379796,
#     'order_id': 2000009301730370,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:27:34.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43843022274},
#   'date_closed': '2024-09-14T20:27:34.000-04:00',
#   'id': 2000009301730370,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB4800036138',
#      'title': 'Tomada Inteligente Wifi Ekaza 10a Com Medição Google Alexa Cor Roxo',
#      'category_id': 'MLB269930',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKGC-T206'},
#     'quantity': 1,
#     'unit_price': 46.58,
#     'full_unit_price': 56.81,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 1},
#     'sale_fee': 11.59,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 4}],
#   'date_last_updated': '2024-09-15T00:47:01+00:00',
#   'last_updated': '2024-09-14T20:47:01.000-04:00',
#   'comment': None,
#   'pack_id': 2000006319944467,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:26:46.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'catalog', 'paid', 'not_delivered'],
#   'buyer': {'id': 80379796, 'nickname': 'RUDINEI_HERMINIO'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 46.58,
#   'paid_amount': 46.58,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': ['catalog']}},
#  {'payments': [{'reason': 'Tomada Inteligente Wifi 20a Alexa Pro Max Ekaza Homol Anatel',
#     'status_code': None,
#     'total_paid_amount': 193.8,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 193.8,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:31:00.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87615999255,
#     'date_last_modified': '2024-09-14T20:31:05.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:30:59.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 1269074507,
#     'order_id': 2000009301747198,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:31:00.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43842853129},
#   'date_closed': '2024-09-14T20:31:00.000-04:00',
#   'id': 2000009301747198,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3746697587',
#      'title': 'Tomada Inteligente Wifi 20a Alexa Pro Max Ekaza Homol Anatel',
#      'category_id': 'MLB269930',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKAT-T205-20A'},
#     'quantity': 4,
#     'unit_price': 48.45,
#     'full_unit_price': 78.99,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 4},
#     'sale_fee': 8.75,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 2}],
#   'date_last_updated': '2024-09-15T00:32:40+00:00',
#   'last_updated': '2024-09-14T20:32:39.000-04:00',
#   'comment': None,
#   'pack_id': 2000006319960777,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:30:58.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'catalog', 'paid', 'not_delivered'],
#   'buyer': {'id': 1269074507, 'nickname': 'TOMWRENN'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 193.8,
#   'paid_amount': 193.8,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': ['catalog']}},
#  {'payments': [{'reason': 'Interruptor Zigbee Inteligente 3 Botões Físicos Smart Alexa Cor Cinza 110v/220v',
#     'status_code': None,
#     'total_paid_amount': 209.6,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 209.6,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:32:50.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87915801152,
#     'date_last_modified': '2024-09-14T20:32:56.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:32:50.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 45385675,
#     'order_id': 2000009301757168,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:32:50.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43843035832},
#   'date_closed': '2024-09-14T20:32:50.000-04:00',
#   'id': 2000009301757168,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3809611097',
#      'title': 'Interruptor Zigbee Inteligente 3 Botões Físicos Smart Alexa Cor Cinza 110v/220v',
#      'category_id': 'MLB269928',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKGD-T408-3ZG'},
#     'quantity': 1,
#     'unit_price': 209.6,
#     'full_unit_price': 246.58,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 1},
#     'sale_fee': 14.24,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 1}],
#   'date_last_updated': '2024-09-15T00:33:45+00:00',
#   'last_updated': '2024-09-14T20:33:44.000-04:00',
#   'comment': None,
#   'pack_id': 2000006319964499,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:32:06.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'catalog', 'paid', 'not_delivered'],
#   'buyer': {'id': 45385675, 'nickname': 'RAMONVALERIO'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 209.6,
#   'paid_amount': 209.6,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': ['catalog']}},
#  {'payments': [{'reason': 'Interruptor Inteligente Novadigital Wi-fi 4 Botões Sem Rf Cor Preto',
#     'status_code': None,
#     'total_paid_amount': 73.15,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 73.15,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:36:23.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87916091000,
#     'date_last_modified': '2024-09-14T20:36:30.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:36:23.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 171746182,
#     'order_id': 2000009301775342,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:36:23.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43843044174},
#   'date_closed': '2024-09-14T20:36:23.000-04:00',
#   'id': 2000009301775342,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3844243083',
#      'title': 'Interruptor Inteligente Novadigital Wi-fi 4 Botões Sem Rf Cor Preto',
#      'category_id': 'MLB269928',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'LITE-WS4-B'},
#     'quantity': 1,
#     'unit_price': 73.15,
#     'full_unit_price': 119.99,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 1},
#     'sale_fee': 10.02,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 2}],
#   'date_last_updated': '2024-09-15T00:55:13+00:00',
#   'last_updated': '2024-09-14T20:55:13.000-04:00',
#   'comment': None,
#   'pack_id': 2000006319976689,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:35:39.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'catalog', 'paid', 'not_delivered'],
#   'buyer': {'id': 171746182, 'nickname': 'JSNNOVAIS'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 73.15,
#   'paid_amount': 73.15,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': ['catalog']}},
#  {'payments': [{'reason': 'Controle Remoto Ir Smart Universal Wi-fi Google Home, Alexa',
#     'status_code': None,
#     'total_paid_amount': 90.19,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 51.39,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:47:24.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': '448212',
#     'taxes_amount': 0,
#     'id': 87916887168,
#     'date_last_modified': '2024-09-14T20:47:30.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 38.8,
#     'installment_amount': 90.19,
#     'date_created': '2024-09-14T20:47:22.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': 9253475081,
#     'status_detail': 'accredited',
#     'issuer_id': '25',
#     'payment_method_id': 'visa',
#     'payment_type': 'credit_card',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 46674186,
#     'order_id': 2000009301837764,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T20:47:24.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43843073608},
#   'date_closed': '2024-09-14T20:47:24.000-04:00',
#   'id': 2000009301837764,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB1844742803',
#      'title': 'Controle Remoto Ir Smart Universal Wi-fi Google Home, Alexa',
#      'category_id': 'MLB38205',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'SRW-003'},
#     'quantity': 1,
#     'unit_price': 51.39,
#     'full_unit_price': 68.9,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 1},
#     'sale_fee': 9.6,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 1}],
#   'date_last_updated': '2024-09-15T05:34:49+00:00',
#   'last_updated': '2024-09-14T21:07:39.000-04:00',
#   'comment': None,
#   'pack_id': None,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T20:47:21.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['paid', 'not_delivered'],
#   'buyer': {'id': 46674186, 'nickname': 'SILLASALEXANDRE_ROD'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 51.39,
#   'paid_amount': 90.19,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': []}},
#  {'payments': [{'reason': 'Hub Zigbee Bridge  Gateway 3.0 + Ble Wifi - Alexa E Google',
#     'status_code': None,
#     'total_paid_amount': 78.09,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 66.09,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T20:49:31.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87916914050,
#     'date_last_modified': '2024-09-14T20:51:56.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 12,
#     'installment_amount': None,
#     'date_created': '2024-09-14T20:48:28.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 144509766,
#     'order_id': 2000009301856632,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None},
#    {'reason': 'Hub Zigbee Bridge  Gateway 3.0 + Ble Wifi - Alexa E Google',
#     'status_code': None,
#     'total_paid_amount': 33.9,
# ...
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T22:30:25.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'mshops', 'paid', 'not_delivered'],
#   'buyer': {'id': 310972470, 'nickname': 'TELMAGUSMOOLIVEIRA'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 239.98,
#   'paid_amount': 239.98,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'mshops',
#    'site': 'MLB',
#    'flows': []}},
#  {'payments': [{'reason': 'Sensor Geonav Hissco Home Intelligence',
#     'status_code': None,
#     'total_paid_amount': 78.99,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 78.99,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T22:31:32.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': '214669',
#     'taxes_amount': 0,
#     'id': 87923388650,
#     'date_last_modified': '2024-09-14T22:32:42.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': 78.99,
#     'date_created': '2024-09-14T22:31:30.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': 9234349279,
#     'status_detail': 'accredited',
#     'issuer_id': '12518',
#     'payment_method_id': 'master',
#     'payment_type': 'credit_card',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 41481408,
#     'order_id': 2000009302400996,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T22:31:33.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43843117701},
#   'date_closed': '2024-09-14T22:31:33.000-04:00',
#   'id': 2000009302400996,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB4819723650',
#      'title': 'Sensor Geonav Hissco Home Intelligence',
#      'category_id': 'MLB7070',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'HISSCO'},
#     'quantity': 1,
#     'unit_price': 78.99,
#     'full_unit_price': 78.99,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 1},
#     'sale_fee': 15.08,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 1}],
#   'date_last_updated': '2024-09-15T02:33:46+00:00',
#   'last_updated': '2024-09-14T22:33:44.000-04:00',
#   'comment': None,
#   'pack_id': None,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T22:31:29.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['catalog', 'paid', 'not_delivered'],
#   'buyer': {'id': 41481408, 'nickname': 'EDMSANTIAGO'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 78.99,
#   'paid_amount': 78.99,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': ['catalog']}},
#  {'payments': [{'reason': 'Interruptor Mini R2 Wifi Automação Alexa E Google Home',
#     'status_code': None,
#     'total_paid_amount': 173.9,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 173.9,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T22:35:24.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87623846015,
#     'date_last_modified': '2024-09-14T22:35:30.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T22:35:24.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 786563002,
#     'order_id': 2000009302428214,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T22:35:24.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43843303896},
#   'date_closed': '2024-09-14T22:35:24.000-04:00',
#   'id': 2000009302428214,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3204702696',
#      'title': 'Interruptor Mini R2 Wifi Automação Alexa E Google Home',
#      'category_id': 'MLB269928',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKHY-T109-WB'},
#     'quantity': 5,
#     'unit_price': 34.78,
#     'full_unit_price': 51.92,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 5},
#     'sale_fee': 10,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 1}],
#   'date_last_updated': '2024-09-15T02:55:31+00:00',
#   'last_updated': '2024-09-14T22:55:30.000-04:00',
#   'comment': None,
#   'pack_id': 2000006320340921,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T22:35:23.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'paid', 'not_delivered'],
#   'buyer': {'id': 786563002, 'nickname': 'FUMO7797161'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 173.9,
#   'paid_amount': 173.9,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': []}},
#  {'payments': [{'reason': 'Interruptor Mini R2 Wifi Automação Alexa E Google Home',
#     'status_code': None,
#     'total_paid_amount': 49.78,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 49.78,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T22:36:05.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87623998495,
#     'date_last_modified': '2024-09-14T22:42:17.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T22:36:05.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 84294272,
#     'order_id': 2000009302428760,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T22:36:06.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43843305204},
#   'date_closed': '2024-09-14T22:36:06.000-04:00',
#   'id': 2000009302428760,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3204702696',
#      'title': 'Interruptor Mini R2 Wifi Automação Alexa E Google Home',
#      'category_id': 'MLB269928',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKHY-T109-WB'},
#     'quantity': 2,
#     'unit_price': 24.89,
#     'full_unit_price': 29.99,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 2},
#     'sale_fee': 0.5,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 1}],
#   'date_last_updated': '2024-09-15T02:42:19+00:00',
#   'last_updated': '2024-09-14T22:42:19.000-04:00',
#   'comment': None,
#   'pack_id': 2000006320345535,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T22:36:03.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'mshops', 'paid', 'not_delivered'],
#   'buyer': {'id': 84294272, 'nickname': 'VADM2005'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 49.78,
#   'paid_amount': 49.78,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'mshops',
#    'site': 'MLB',
#    'flows': []}},
#  {'payments': [{'reason': 'Lâmpada Inteligente Ekaza Ekhm-t609 Rgb A60 9w+3rgb Smart Alexa E Google Home',
#     'status_code': None,
#     'total_paid_amount': 128,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 128,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T22:40:16.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87624140891,
#     'date_last_modified': '2024-09-14T22:41:25.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T22:40:16.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 90474037,
#     'order_id': 2000009302442964,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T22:40:17.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43843311756},
#   'date_closed': '2024-09-14T22:40:17.000-04:00',
#   'id': 2000009302442964,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB3891206678',
#      'title': 'Lâmpada Inteligente Ekaza Ekhm-t609 Rgb A60 9w+3rgb Smart Alexa E Google Home',
#      'category_id': 'MLB8462',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKGC-T261-E27'},
#     'quantity': 4,
#     'unit_price': 32,
#     'full_unit_price': 40,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 4},
#     'sale_fee': 9.68,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 1}],
#   'date_last_updated': '2024-09-15T02:41:52+00:00',
#   'last_updated': '2024-09-14T22:41:51.000-04:00',
#   'comment': None,
#   'pack_id': 2000006320356187,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T22:40:14.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'catalog', 'paid', 'not_delivered'],
#   'buyer': {'id': 90474037, 'nickname': 'LORENASDUTRA'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 128,
#   'paid_amount': 128,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': ['catalog']}},
#  {'payments': [{'reason': 'Tomada Inteligente Smart Wifi Controle Automação Ekaza 16a',
#     'status_code': None,
#     'total_paid_amount': 203.96,
#     'operation_type': 'regular_payment',
#     'transaction_amount': 203.96,
#     'transaction_amount_refunded': 0,
#     'date_approved': '2024-09-14T22:47:28.000-04:00',
#     'collector': {'id': 189643563},
#     'coupon_id': None,
#     'installments': 1,
#     'authorization_code': None,
#     'taxes_amount': 0,
#     'id': 87624460961,
#     'date_last_modified': '2024-09-14T22:47:33.000-04:00',
#     'coupon_amount': 0,
#     'available_actions': ['refund'],
#     'shipping_cost': 0,
#     'installment_amount': None,
#     'date_created': '2024-09-14T22:47:28.000-04:00',
#     'activation_uri': None,
#     'overpaid_amount': 0,
#     'card_id': None,
#     'status_detail': 'accredited',
#     'issuer_id': '2007',
#     'payment_method_id': 'account_money',
#     'payment_type': 'account_money',
#     'deferred_period': None,
#     'atm_transfer_reference': {'transaction_id': None, 'company_id': None},
#     'site_id': 'MLB',
#     'payer_id': 127748213,
#     'order_id': 2000009302471754,
#     'currency_id': 'BRL',
#     'status': 'approved',
#     'transaction_order_id': None}],
#   'fulfilled': None,
#   'taxes': {'amount': None, 'currency_id': None, 'id': None},
#   'order_request': {'change': None, 'return': None},
#   'expiration_date': '2024-10-12T22:47:28.000-04:00',
#   'feedback': {'buyer': None, 'seller': None},
#   'shipping': {'id': 43843144761},
#   'date_closed': '2024-09-14T22:47:28.000-04:00',
#   'id': 2000009302471754,
#   'manufacturing_ending_date': None,
#   'order_items': [{'item': {'id': 'MLB4587629126',
#      'title': 'Tomada Inteligente Smart Wifi Controle Automação Ekaza 16a',
#      'category_id': 'MLB269930',
#      'variation_id': None,
#      'seller_custom_field': None,
#      'global_price': None,
#      'net_weight': None,
#      'variation_attributes': [],
#      'warranty': 'Garantia de fábrica: 12 meses',
#      'condition': 'new',
#      'seller_sku': 'EKNX-T005'},
#     'quantity': 4,
#     'unit_price': 50.99,
#     'full_unit_price': 73.9,
#     'currency_id': 'BRL',
#     'manufacturing_days': None,
#     'picked_quantity': None,
#     'requested_quantity': {'measure': 'unit', 'value': 4},
#     'sale_fee': 11.97,
#     'listing_type_id': 'gold_special',
#     'base_exchange_rate': None,
#     'base_currency_id': None,
#     'bundle': None,
#     'element_id': 1}],
#   'date_last_updated': '2024-09-15T05:51:16+00:00',
#   'last_updated': '2024-09-14T23:07:41.000-04:00',
#   'comment': None,
#   'pack_id': 2000006320375257,
#   'coupon': {'amount': 0, 'id': None},
#   'shipping_cost': None,
#   'date_created': '2024-09-14T22:47:27.000-04:00',
#   'pickup_id': None,
#   'status_detail': None,
#   'tags': ['pack_order', 'catalog', 'paid', 'not_delivered'],
#   'buyer': {'id': 127748213, 'nickname': 'JESSEOLIVEIRA539'},
#   'seller': {'id': 189643563, 'nickname': 'HUBSMARTHOME.COM.BR'},
#   'total_amount': 203.96,
#   'paid_amount': 203.96,
#   'currency_id': 'BRL',
#   'status': 'paid',
#   'context': {'application': None,
#    'product_id': None,
#    'channel': 'marketplace',
#    'site': 'MLB',
#    'flows': ['catalog']}}]

# %%
data = request
store_name = data.get('store_name')
seller_id = data.get('seller_id')
print('** Connecting to storage and BigQuery... **')
# Initialize storage and BigQuery
storage = CloudStorage(credentials_path=settings.PATH_SERVICE_ACCOUNT)
bigquery = BigQueryManager(credentials_path=settings.PATH_SERVICE_ACCOUNT)
# Define paths and table names from the config
bucket_name = settings.BUCKET_STORES
table_management = settings.TABLE_MANAGEMENT
destiny_table = settings.TABLE_ORDERS
blob_shipping_cost = settings.BLOB_ORDERS(store_name)
# Define today's date
today_str = datetime.today().strftime('%Y-%m-%d')
# Get dates to treat
list_dates_to_process = bigquery.get_list_dates_to_process(seller_id, table_management, destiny_table)
print(f'*** Starting to process dates: {len(list_dates_to_process)} dates to process  ***')
df_processed_data = pd.DataFrame()
for i in range(2):
        # Transform date to string
        #date_to_process = date.strftime('%Y-%m-%d')
    date_to_process = '2024-09-15'
    print(f'Processing date: {date_to_process}')
    # Get blob with the date
    blob_prefix = blob_shipping_cost + f'date={date_to_process}/'
    # List all the files
    blobs = storage.list_blobs(bucket_name, blob_prefix)
    # Processing each blob
    for blob in blobs:
        print(f"Reading file: {blob.name}")
        content = storage.download_json(bucket_name, blob.name)
        for json in content:
            df_processed_data = process_orders(json['results'])
            
        df_processed_data = pd.concat([df_processed_data, df_], ignore_index = True)
        
    df_processed_data['correspondent_date'] = pd.to_datetime(date_to_process)
    df_processed_data['process_time'] = datetime.now()
# Out:
# ** Connecting to storage and BigQuery... **
# Using local credentials from: C:/Users/User/Documents/papa preco/service account/service_account_datalakev2.json
# Using local credentials from: C:/Users/User/Documents/papa preco/service account/service_account_datalakev2.json
# *** Starting to process dates: 369 dates to process  ***
# Processing date: 2024-09-15
# Reading file: hubsmarthome/meli/api_response/orders/date=2024-09-15/total_sales=457__processing-date=2024-09-16T19:43:43.429042-03:00.json
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 32
#      30 print(f"Reading file: {blob.name}")
#      31 content = storage.download_json(bucket_name, blob.name)
# ---> 32 sales = content['results']
#      33 for json in content:
#      34     df_processed_data = process_orders(json['results'])
#
# TypeError: list indices must be integers or slices, not str

# %%
len(content)
# Out:
# 10
